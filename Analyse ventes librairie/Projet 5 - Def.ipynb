# %% [markdown]
# ## Projet 5 - Bottle Neck
# **Importations**
# - <a href='#C1'> Import librairies </a>
# - <a href='#C2'> Import fichiers </a>
#
# **Nettoyage données**
# - <a href='#C3'> Affichage des tables </a>
# - <a href='#C4'> Contrôle des tables </a>
# - <a href='#C5'> Nettoyage table web </a>
#
# **Merge des tables**
# - <a href='#C6'> Merge des tables </a>
#
# **Calculs**
# - <a href='#C7'> Calculs CA </a>
#
# **Étude des prix**
# - <a href='#C8'> Boxplot et Zscore </a>

# %% [markdown]
# ### <a name='C1'> Import librairies </a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### <a name='C2'>Import fichiers </a>

# %%
prc = 'C:/Users/Zacca/OneDrive/Desktop/Desktop_Google/PortFolio/Progetto 5/File/'

# %%
liaison = pd.read_excel(prc + 'liaison.xlsx')
erp = pd.read_excel(prc + 'erp.xlsx')
web = pd.read_excel(prc + 'web.xlsx')

# %% [markdown]
# ### <a name='C3'> Affichage des tables </a>
# On commence avec un première affichage des tables importé

# %%
erp.head(3)
# Out:
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock

# %%
liaison.head(3)
# Out:
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300

# %%
web.head(3)
# Out:
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  ...  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41  ...
#
#                                      post_name       post_modified  \
# 0                       bon-cadeau-de-25-euros 2018-06-01 14:13:57
# 1  pierre-jean-villa-saint-joseph-preface-2018 2019-12-30 09:30:29
# 2    pierre-jean-villa-saint-joseph-tilde-2017 2019-12-21 09:00:17
#
#     post_modified_gmt post_content_filtered post_parent  \
# 0 2018-06-01 12:13:57                   NaN         0.0
# 1 2019-12-30 08:30:29                   NaN         0.0
# 2 2019-12-21 08:00:17                   NaN         0.0
#
#                                                         guid menu_order  \
# 0  https://www.bottle-neck.fr/?post_type=product&#038;p=4954        0.0
# 1  https://www.bottle-neck.fr/?post_type=product&#038;p=3847        0.0
# 2  https://www.bottle-neck.fr/?post_type=product&#038;p=3849        0.0
#
#    post_type post_mime_type comment_count
# 0    product            NaN           0.0
# 1    product            NaN           0.0
# 2    product            NaN           0.0
#
# [3 rows x 28 columns]

# %% [markdown]
# - Dans la table web on observe qu'il y a plusieurs colonnes qui ne serts pas aux requêtes du projet.
# On peut aussi observer plusieurs valeurs NaN à traiter.

# %% [markdown]
# ### <a name='C4'> Contrôle des tables </a>
# Maintenant on vas observer d'une façon générale les numero des valeurs dans chaque table et les valeurs nulles

# %%
print('erp :',erp.shape)
print('liaison :',liaison.shape)
print('web :', web.shape)
# Out:
# erp : (825, 5)
# liaison : (825, 2)
# web : (1513, 28)

# %%
# affichage des valeurs nulles pour la table erp
erp.isnull().sum()
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64

# %%
# affichage des valeurs nulles pour la table liaison
liaison.isnull().sum()
# Out:
# product_id     0
# id_web        91
# dtype: int64

# %%
# affichage des valeurs nulles pour la table web
web.isnull().sum()
# Out:
# sku                        85
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating             83
# total_sales                83
# tax_status                797
# tax_class                1513
# post_author                83
# post_date                  83
# post_date_gmt              83
# post_content             1513
# post_title                 83
# post_excerpt              797
# post_status                83
# comment_status             83
# ping_status                83
# post_password            1513
# post_name                  83
# post_modified              83
# post_modified_gmt          83
# post_content_filtered    1513
# post_parent                83
# guid                       83
# menu_order                 83
# post_type                  83
# post_mime_type            799
# comment_count              83
# dtype: int64

# %% [markdown]
# - On peut voir comment, dans la table erp, et liaison, on as le memes numero de lignes
# - Dans la table web, et pour les valeurs id_web, on observer divers valeurs nulles à traiter

# %% [markdown]
# ### <a name='C5'> Nettoyage table web </a>
# On se concentre maintenant sur la table web pour effectuer les manipulation nécessaires pour préparer la table aux jointures

# %% [markdown]
# Pour simplifier la visualisation des la table, on vas supprimer les colonnes qui ne senmble pas être nécessaires à notres manipulations

# %%
# creation variable avec les colonnes a dropper
to_drop = ['virtual','downloadable','rating_count','average_rating','tax_class','post_author','post_date','post_modified','post_modified_gmt','post_content','post_content_filtered','post_parent','menu_order','post_mime_type','comment_count','post_date_gmt','post_excerpt','comment_status','ping_status','post_password']

# %%
# drop des colonnes contenu dans la variable to_drop
web.drop(columns=to_drop, inplace=True)

# %% [markdown]
# Maintenant on va prendre un valeur de la table pour la observer de plus près

# %%
# recherche valeur dans la table
web[web['sku'] == 15298]
# Out:
#        sku  total_sales tax_status  \
# 1    15298          6.0    taxable
# 799  15298          6.0        NaN
#
#                                       post_title post_status  \
# 1    Pierre Jean Villa Saint-Joseph Préface 2018     publish
# 799  Pierre Jean Villa Saint-Joseph Préface 2018     publish
#
#                                        post_name  \
# 1    pierre-jean-villa-saint-joseph-preface-2018
# 799  pierre-jean-villa-saint-joseph-preface-2018
#
#                                                                                                     guid  \
# 1                                              https://www.bottle-neck.fr/?post_type=product&#038;p=3847
# 799  https://www.bottle-neck.fr/wp-content/uploads/2020/03/pierre-jean-villa-saint-joseph-preface-201...
#
#       post_type
# 1       product
# 799  attachment

# %% [markdown]
# - On peut observer qu'il y a un repetition qui est lié a la colonne post_type

# %% [markdown]
# On vas alors procéder à la suppression des doublons liés a la problématique de la colonne post_type

# %%
# suppression des doublons
web.drop(web.loc[web['post_type'] == 'attachment'].index, inplace = True)

# %% [markdown]
# Maintenant on va verifier si la valeur 'sku' est unique, où si on as encore des doublons

# %%
# on verifie si la colonne sku contiennent des valeur distinctes
web.sku.is_unique
# Out:
# False

# %% [markdown]
# On va controller quelles sont les doublons restantes

# %%
web.loc[web['sku'].duplicated(keep=False),:]
# Out:
#      sku  total_sales tax_status post_title post_status post_name guid  \
# 178  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 179  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 227  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 230  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 231  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# ..   ...          ...        ...        ...         ...       ...  ...
# 792  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 793  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 794  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 795  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 796  NaN          NaN        NaN        NaN         NaN       NaN  NaN
#
#     post_type
# 178       NaN
# 179       NaN
# 227       NaN
# 230       NaN
# 231       NaN
# ..        ...
# 792       NaN
# 793       NaN
# 794       NaN
# 795       NaN
# 796       NaN
#
# [85 rows x 8 columns]

# %% [markdown]
# On peut maintenant verifier pour chaque colonnes le nombre des valeurs nulles

# %%
# contrôle des valeurs nulles dans la table web
web.isnull().sum()
# Out:
# sku            85
# total_sales    83
# tax_status     83
# post_title     83
# post_status    83
# post_name      83
# guid           83
# post_type      83
# dtype: int64

# %% [markdown]
# - on observe que les valeurs nulles dans la colonne 'sku' sont 85, contre 83 des autres colonnes

# %% [markdown]
# On essaye d'extraire les deux valeurs qui ne sont pas nulles

# %%
# verfication des valeurs nulles
web.loc[web['sku'].duplicated(keep=False),:].sort_values(by='post_title')
# Out:
#      sku  total_sales tax_status  \
# 471  NaN          0.0    taxable
# 470  NaN          0.0    taxable
# 178  NaN          NaN        NaN
# 179  NaN          NaN        NaN
# 227  NaN          NaN        NaN
# ..   ...          ...        ...
# 792  NaN          NaN        NaN
# 793  NaN          NaN        NaN
# 794  NaN          NaN        NaN
# 795  NaN          NaN        NaN
# 796  NaN          NaN        NaN
#
#                                           post_title post_status  \
# 471  Pierre Jean Villa Condrieu Jardin Suspendu 2018     publish
# 470       Pierre Jean Villa Côte Rôtie Fongeant 2017     publish
# 178                                              NaN         NaN
# 179                                              NaN         NaN
# 227                                              NaN         NaN
# ..                                               ...         ...
# 792                                              NaN         NaN
# 793                                              NaN         NaN
# 794                                              NaN         NaN
# 795                                              NaN         NaN
# 796                                              NaN         NaN
#
#                                       post_name  \
# 471    pierre-jean-villa-condrieu-suspendu-2018
# 470  pierre-jean-villa-cote-rotie-fongeant-2017
# 178                                         NaN
# 179                                         NaN
# 227                                         NaN
# ..                                          ...
# 792                                         NaN
# 793                                         NaN
# 794                                         NaN
# 795                                         NaN
# 796                                         NaN
#
#                                                           guid post_type
# 471  https://www.bottle-neck.fr/?post_type=product&#038;p=5075   product
# 470  https://www.bottle-neck.fr/?post_type=product&#038;p=5070   product
# 178                                                        NaN       NaN
# 179                                                        NaN       NaN
# 227                                                        NaN       NaN
# ..                                                         ...       ...
# 792                                                        NaN       NaN
# 793                                                        NaN       NaN
# 794                                                        NaN       NaN
# 795                                                        NaN       NaN
# 796                                                        NaN       NaN
#
# [85 rows x 8 columns]

# %% [markdown]
# - on as deux produit qui ont pas leur web_id

# %% [markdown]
# On étude un autre valeur pour voir si on peut arriver aux valeurs nulles

# %%
# on augmente les caractères pour bien visualiser la string
pd.set_option("display.max_colwidth", 100)
# on prend un valeur de la colonne 'guid'
web.loc[1]
# Out:
# sku                                                                15298
# total_sales                                                          6.0
# tax_status                                                       taxable
# post_title                   Pierre Jean Villa Saint-Joseph Préface 2018
# post_status                                                      publish
# post_name                    pierre-jean-villa-saint-joseph-preface-2018
# guid           https://www.bottle-neck.fr/?post_type=product&#038;p=3847
# post_type                                                        product
# Name: 1, dtype: object

# %% [markdown]
# Si on observe le valeur de la colonne guid, on voit 4 nombres, on vas verifier si on peut etablir a quoi ils se referent

# %%
# recherche valeur dans la table liaison
liaison[liaison['product_id'] == 3847]
# Out:
#    product_id id_web
# 0        3847  15298

# %% [markdown]
# En effet, si on considère le code trouvé preceprécédemment, on peut verifier que il représente le product_id

# %%
# filtre pour trouver le guid des valeurs qui ont pas leur sku
web.loc[web['sku'].duplicated(keep=False),:].sort_values(by='post_title').head(2)
# Out:
#      sku  total_sales tax_status  \
# 471  NaN          0.0    taxable
# 470  NaN          0.0    taxable
#
#                                           post_title post_status  \
# 471  Pierre Jean Villa Condrieu Jardin Suspendu 2018     publish
# 470       Pierre Jean Villa Côte Rôtie Fongeant 2017     publish
#
#                                       post_name  \
# 471    pierre-jean-villa-condrieu-suspendu-2018
# 470  pierre-jean-villa-cote-rotie-fongeant-2017
#
#                                                           guid post_type
# 471  https://www.bottle-neck.fr/?post_type=product&#038;p=5075   product
# 470  https://www.bottle-neck.fr/?post_type=product&#038;p=5070   product

# %%
# filtre pour trouver le valeurs sku dans la table liaison
liaison[liaison['product_id'] == 5070]
# Out:
#      product_id id_web
# 486        5070    NaN

# %%
liaison[liaison['product_id'] == 5075]
# Out:
#      product_id id_web
# 487        5075    NaN

# %% [markdown]
# Les deux valeurs ont pas un id_web, alors on va en creer deux pour fixe les problème

# %%
# on verfiie que il n'y a pas des elements avec cette sku
web[web['sku'] == 10001]
# Out:
# Empty DataFrame
# Columns: [sku, total_sales, tax_status, post_title, post_status, post_name, guid, post_type]
# Index: []

# %%
web[web['sku'] == 10002]
# Out:
# Empty DataFrame
# Columns: [sku, total_sales, tax_status, post_title, post_status, post_name, guid, post_type]
# Index: []

# %%
# on insere les nouveaux valeurs dans la table web et liaison
web.at[470,'sku'] = 10001
web.at[471,'sku'] = 10002
liaison.at[486,'id_web']  = 10001 
liaison.at[487,'id_web']  = 10002

# %%
# on verifie que le changement à été enregistré 
web[web['sku'] == 10001]
# Out:
#        sku  total_sales tax_status  \
# 470  10001          0.0    taxable
#
#                                      post_title post_status  \
# 470  Pierre Jean Villa Côte Rôtie Fongeant 2017     publish
#
#                                       post_name  \
# 470  pierre-jean-villa-cote-rotie-fongeant-2017
#
#                                                           guid post_type
# 470  https://www.bottle-neck.fr/?post_type=product&#038;p=5070   product

# %% [markdown]
# On verifie a nouveaux les valeurs doublons et les valeurs nulles

# %%
# recherche de valeurs doublons
web.loc[web['sku'].duplicated(keep=False),:]
# Out:
#      sku  total_sales tax_status post_title post_status post_name guid  \
# 178  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 179  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 227  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 230  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 231  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# ..   ...          ...        ...        ...         ...       ...  ...
# 792  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 793  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 794  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 795  NaN          NaN        NaN        NaN         NaN       NaN  NaN
# 796  NaN          NaN        NaN        NaN         NaN       NaN  NaN
#
#     post_type
# 178       NaN
# 179       NaN
# 227       NaN
# 230       NaN
# 231       NaN
# ..        ...
# 792       NaN
# 793       NaN
# 794       NaN
# 795       NaN
# 796       NaN
#
# [83 rows x 8 columns]

# %%
# recherche des valeurs nulles
web.isnull().sum()
# Out:
# sku            83
# total_sales    83
# tax_status     83
# post_title     83
# post_status    83
# post_name      83
# guid           83
# post_type      83
# dtype: int64

# %%
# drop des lignes NaN de la table
web.dropna(inplace=True)

# %% [markdown]
# On change le nom de la colonne sku en id_web pour simplifier les rapprochements

# %%
# changement de nom de la colonne sku
web.rename(columns={'sku' : 'id_web'}, inplace=True)

# %% [markdown]
# ### <a name='C6'> Merge des tables </a>
# On vas faire les rapprochements des tables

# %% [markdown]
# Tout d'abord on vas contrôler si on trouve les clés primaries

# %%
# controle le product_id
erp.product_id.is_unique
# Out:
# True

# %%
# controle id_web
web.id_web.is_unique
# Out:
# True

# %%
# Controle table liaison
liaison.isnull().sum()
# Out:
# product_id     0
# id_web        89
# dtype: int64

# %% [markdown]
# Il y a des valeurs nulles dans la colonne id_web de la table liaison
# Il correspondent aux valeurs NaN vue précédemment dans l'analyse de chaque table.

# %%
# on drop les valeurs NaN de la table liaison pour la preparer pour les jointures
liaison.dropna(inplace=True)

# %%
# on controle les valeurs nulles dans la table liaison
liaison.isnull().sum()
# Out:
# product_id    0
# id_web        0
# dtype: int64

# %% [markdown]
# Maintenant on vas procéder avec les jointures

# %% [markdown]
# On effectue des jointure, en ajoutant la méthode validate 1:1 qui contrôle si il y a effectivement des relation un as un entre les clés primaires des tables.

# %%
# merge entre table erp et liaison inner, avec condition validate 1:1 
erp_lia = pd.merge(erp, liaison, on='product_id', validate='1:1')

# %%
# merge entre table erp_lia et table web, avec condition validate 1:1
table_merge = pd.merge(erp_lia, web, on= 'id_web', validate='1:1', indicator=True )

# %%
# contrôle des valeurs both
print('il y a ', len(table_merge[table_merge['_merge'] != 'both']), 'valeur both')
# Out:
# il y a  0 valeur both

# %%
# drop colonne _merge
table_merge.drop('_merge', axis ='columns', inplace = True)

# %%
# affichage de la table_merge
table_merge.head(3)
# Out:
#    product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 0        3847           1   24.2               0   outofstock  15298
# 1        3849           1   34.3               0   outofstock  15296
# 2        3850           1   20.8               0   outofstock  15300
#
#    total_sales tax_status  \
# 0          6.0    taxable
# 1          0.0    taxable
# 2          0.0    taxable
#
#                                                post_title post_status  \
# 0             Pierre Jean Villa Saint-Joseph Préface 2018     publish
# 1         Pierre Jean Villa Saint-Joseph Rouge Tildé 2017     publish
# 2  Pierre Jean Villa Crozes-Hermitage Accroche Coeur 2018     publish
#
#                                                post_name  \
# 0            pierre-jean-villa-saint-joseph-preface-2018
# 1              pierre-jean-villa-saint-joseph-tilde-2017
# 2  pierre-jean-villa-croze-hermitage-accroche-coeur-2018
#
#                                                         guid post_type
# 0  https://www.bottle-neck.fr/?post_type=product&#038;p=3847   product
# 1  https://www.bottle-neck.fr/?post_type=product&#038;p=3849   product
# 2  https://www.bottle-neck.fr/?post_type=product&#038;p=3850   product

# %% [markdown]
# ### <a name='C7'> Calculs </a>
# Maintenant on va proceder aux calculs des chiffre d'affaires

# %% [markdown]
# Tout d'abord on vas créer un nouvelle colonne avec le calcul de CA pour chaque produit

# %%
# nouvelle colonne appelé CA 
table_merge['CA'] = table_merge['price'] * table_merge['total_sales']

# %% [markdown]
# Maintenant on vas faire la somme des tous les CA pous afficher le CA total

# %%
# somme des CA
Chiffre_Affaires = table_merge['CA'].sum()

# %%
# affichage du total
print('Le CA total est de: ', Chiffre_Affaires, '€')
# Out:
# Le CA total est de:  70568.6 €

# %% [markdown]
# ### <a name='C8'> Etude des prix </a>
# On vois de plus près le comportement des outliers et des valeurs aberrantes

# %%
table_merge['price'].describe()
# Out:
# count    716.000000
# mean      32.581145
# std       27.842942
# min        5.200000
# 25%       14.100000
# 50%       23.650000
# 75%       42.300000
# max      225.000000
# Name: price, dtype: float64

# %% [markdown]
# On vas essayer de visualiser le comportement des prix avec un boxplot

# %%
# creation et affichage du box plot
sns.boxplot(x=table_merge['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# On peut observer que les valeurs se concentrent au dessous de 50 euros, mais on vois plusieurs outliers

# %% [markdown]
# On va essayer aussi avec la méthode du Zscore, pour créer une graphique en nuage de points qui va mettre en evidence les outliers

# %%
# on vas créer une nouvelle colonne pour les valeurs ZScore
table_merge['zscore'] = stats.zscore(table_merge['price'])

# %%
# on vas créer une variable pour pouvoir mettre en valeurs les outliers
table_zscore = table_merge.loc[(table_merge['zscore'] > 1.96) | (table_merge['zscore'] < -1.96)]

# %%
# affichage des outliers
table_merge.loc[(table_merge['zscore'] > 1.96) | (table_merge['zscore'] < -1.96)]
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 63         4115           1  100.0              11      instock  15382
# 65         4132           1   88.4               5      instock  11668
# 199        4352           1  225.0               0   outofstock  15940
# 201        4355           1  126.5               2      instock  12589
# 218        4402           1  176.0               8      instock   3510
# 219        4404           1  108.5               2      instock   3507
# 221        4406           1  157.0               3      instock   7819
# 222        4407           1  104.0               6      instock   3509
# 227        4582           1  109.6               7      instock  12857
# 380        4903           1  102.3              20      instock  14805
# 381        4904           1  137.0              13      instock  14220
# 426        5001           1  217.5              20      instock  14581
# 431        5007           1  105.0              17      instock  12791
# 432        5008           1  105.0              10      instock  11602
# 437        5025           1  112.0               0   outofstock  13914
# 504        5565           1   92.0               0   outofstock  19822
# 513        5612           1  124.8              12      instock  14915
# 555        5767           1  175.0              12      instock  15185
# 589        5892           1  191.3              10      instock  14983
# 604        5916           1   93.0               3      instock  14774
# 605        5917           1  122.0               4      instock  14775
# 606        5918           1  114.0               8      instock  14773
# 644        6126           1  135.0              10      instock  14923
# 649        6201           1  105.6               7      instock  14596
# 650        6202           1  116.4              14      instock  15126
# 655        6212           1  115.0               2      instock  13996
# 656        6213           1  121.0               7      instock  15072
# 657        6214           1   99.0               7      instock  11601
# 658        6215           1  115.0               4      instock  12790
# 659        6216           1  121.0               6      instock  15070
#
#      total_sales tax_status  \
# 63           0.0    taxable
# 65           0.0    taxable
# 199          5.0    taxable
# 201         11.0    taxable
# 218         13.0    taxable
# 219          2.0    taxable
# 221          0.0    taxable
# 222          1.0    taxable
# 227          0.0    taxable
# 380          0.0    taxable
# 381          5.0    taxable
# 426          0.0    taxable
# 431          0.0    taxable
# 432          0.0    taxable
# 437          0.0    taxable
# 504          0.0    taxable
# 513          0.0    taxable
# 555          0.0    taxable
# 589          3.0    taxable
# 604          0.0    taxable
# 605          0.0    taxable
# 606          0.0    taxable
# 644          2.0    taxable
# 649          0.0    taxable
# 650          0.0    taxable
# 655          2.0    taxable
# 656          0.0    taxable
# 657          0.0    taxable
# 658          0.0    taxable
# 659          0.0    taxable
#
#                                                                              post_title  \
# 63             Zind-Humbrecht Riesling Grand Cru Rangen De Thann Clos Saint-Urbain 2017
# 65           Zind-Humbrecht Pinot Gris Grand Cru Rangen De Thann Clos Saint-Urbain 2012
# 199                                      Champagne Egly-Ouriet Grand Cru Millésimé 2008
# 201                                      Champagne Egly-Ouriet Grand Cru Blanc de Noirs
# 218                                                                Cognac Frapin VIP XO
# 219                                               Cognac Frapin Château de Fontpinot XO
# 221                                Cognac Frapin Château de Fontpinot 1989 20 Ans d'Age
# 222                                                           Cognac Frapin Cigar Blend
# 227                    Château de Meursault Puligny-Montrachet 1er Cru Champ Canet 2014
# 380                                  Domaine Des Croix Corton Grand Cru Les Grèves 2017
# 381                                 Domaine Des Croix Corton Charlemagne Grand Cru 2016
# 426                                      David Duband Charmes-Chambertin Grand Cru 2014
# 431                    Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2014
# 432                    Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2013
# 437  Champagne Agrapart &amp; Fils L'Avizoise Extra Brut Blanc de Blancs Grand Cru 2012
# 504                                                       Tempier Bandol Cabassaou 2017
# 513                   Domaine Weinbach Gewurztraminer Grand Cru Furstentum SGN 2010 1/2
# 555                                                 Camille Giroud Clos de Vougeot 2016
# 589                                  Coteaux Champenois Egly-Ouriet Ambonnay Rouge 2016
# 604         Wemyss Malts Single Cask Scotch Whisky Chocolate Moka Cake 2005 Strathclyde
# 605       Wemyss Malts Single Cask Scotch Whisky Choc 'n' Nut Pretzel 2001 Bunnahabhain
# 606        Wemyss Malts Single Cask Scotch Whisky Chai Caramel Latte 2002 Craigellachie
# 644                                              Champagne Gosset Célébris Vintage 2007
# 649                            David Duband Chambolle-Musigny 1er Cru Les Sentiers 2016
# 650                                 Domaine Clerget Echezeaux Grand Cru En Orveaux 2015
# 655                    Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2015
# 656                    Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2016
# 657                               Domaine des Comtes Lafon Volnay 1er Cru Champans 2013
# 658                               Domaine des Comtes Lafon Volnay 1er Cru Champans 2014
# 659                               Domaine des Comtes Lafon Volnay 1er Cru Champans 2016
#
#     post_status  \
# 63      publish
# 65      publish
# 199     publish
# 201     publish
# 218     publish
# 219     publish
# 221     publish
# 222     publish
# 227     publish
# 380     publish
# 381     publish
# 426     publish
# 431     publish
# 432     publish
# 437     publish
# 504     publish
# 513     publish
# 555     publish
# 589     publish
# 604     publish
# 605     publish
# 606     publish
# 644     publish
# 649     publish
# 650     publish
# 655     publish
# 656     publish
# 657     publish
# 658     publish
# 659     publish
#
#                                                                        post_name  \
# 63                   zind-humbrecht-riesling-gc-rangen-thann-clos-st-urbain-2017
# 65    zind-humbrecht-pinot-gris-grand-cru-rangen-de-thann-clos-saint-urbain-2012
# 199                               champagne-egly-ouriet-grand-cru-millesime-2008
# 201                          champagne-egly-ouriet-grand-cru-brut-blanc-de-noirs
# 218                                                         cognac-frapin-vip-xo
# 219                                                   cognac-frapin-fontpinot-xo
# 221                               cognac-frapin-chateau-de-fontpinot-1989-20-ans
# 222                                                    cognac-frapin-cigar-blend
# 227                          chateau-de-puligny-montrachet-1cru-champ-canet-2014
# 380                           domaine-des-croix-corton-grand-cru-les-greves-2017
# 381                          domaine-des-croix-corton-charlemagne-grand-cru-2016
# 426                               david-duband-charmes-chambertin-grand-cru-2014
# 431             domaine-des-comtes-lafon-volnay-1er-cru-santenots-du-milieu-2014
# 432             domaine-des-comtes-lafon-volnay-1er-cru-santenots-du-milieu-2013
# 437  champagne-agrapart-fils-lavizoise-grand-cru-2012-extra-brut-blanc-de-blancs
# 504                                                tempier-bandol-cabassaou-2017
# 513                       domaine-weinbach-gewurztraminer-gc-furstentum-sgn-2010
# 555                                          camille-giroud-clos-de-vougeot-2016
# 589                           coteaux-champenois-egly-ouriet-ambonnay-rouge-2016
# 604                                 wemyss-malts-single-cask-chocolate-moka-cake
# 605               wemyss-malts-single-cask-scotch-whisky-choc-n-nut-pretzel-2001
# 606               wemyss-malts-single-cask-scotch-whisky-chai-caramel-latte-2002
# 644                                       champagne-gosset-celebris-vintage-2007
# 649                     david-duband-chambolle-musigny-1er-cru-les-sentiers-2016
# 650                                    domaine-clerget-echezeaux-en-orveaux-2015
# 655             domaine-des-comtes-lafon-volnay-1er-cru-santenots-du-milieu-2015
# 656             domaine-des-comtes-lafon-volnay-1er-cru-santenots-du-milieu-2016
# 657                        domaine-des-comtes-lafon-volnay-1er-cru-champans-2013
# 658                        domaine-des-comtes-lafon-volnay-1er-cru-champans-2014
# 659                        domaine-des-comtes-lafon-volnay-1er-cru-champans-2016
#
#                                                           guid post_type  \
# 63   https://www.bottle-neck.fr/?post_type=product&#038;p=4115   product
# 65   https://www.bottle-neck.fr/?post_type=product&#038;p=4132   product
# 199  https://www.bottle-neck.fr/?post_type=product&#038;p=4352   product
# 201  https://www.bottle-neck.fr/?post_type=product&#038;p=4355   product
# 218  https://www.bottle-neck.fr/?post_type=product&#038;p=4402   product
# 219  https://www.bottle-neck.fr/?post_type=product&#038;p=4404   product
# 221  https://www.bottle-neck.fr/?post_type=product&#038;p=4406   product
# 222  https://www.bottle-neck.fr/?post_type=product&#038;p=4407   product
# 227  https://www.bottle-neck.fr/?post_type=product&#038;p=4582   product
# 380  https://www.bottle-neck.fr/?post_type=product&#038;p=4903   product
# 381  https://www.bottle-neck.fr/?post_type=product&#038;p=4904   product
# 426  https://www.bottle-neck.fr/?post_type=product&#038;p=5001   product
# 431  https://www.bottle-neck.fr/?post_type=product&#038;p=5007   product
# 432  https://www.bottle-neck.fr/?post_type=product&#038;p=5008   product
# 437  https://www.bottle-neck.fr/?post_type=product&#038;p=5025   product
# 504  https://www.bottle-neck.fr/?post_type=product&#038;p=5565   product
# 513  https://www.bottle-neck.fr/?post_type=product&#038;p=5612   product
# 555  https://www.bottle-neck.fr/?post_type=product&#038;p=5767   product
# 589  https://www.bottle-neck.fr/?post_type=product&#038;p=5892   product
# 604  https://www.bottle-neck.fr/?post_type=product&#038;p=5916   product
# 605  https://www.bottle-neck.fr/?post_type=product&#038;p=5917   product
# 606  https://www.bottle-neck.fr/?post_type=product&#038;p=5918   product
# 644  https://www.bottle-neck.fr/?post_type=product&#038;p=6126   product
# 649  https://www.bottle-neck.fr/?post_type=product&#038;p=6201   product
# 650  https://www.bottle-neck.fr/?post_type=product&#038;p=6202   product
# 655  https://www.bottle-neck.fr/?post_type=product&#038;p=6212   product
# 656  https://www.bottle-neck.fr/?post_type=product&#038;p=6213   product
# 657  https://www.bottle-neck.fr/?post_type=product&#038;p=6214   product
# 658  https://www.bottle-neck.fr/?post_type=product&#038;p=6215   product
# 659  https://www.bottle-neck.fr/?post_type=product&#038;p=6216   product
#
#          CA    zscore
# 63      0.0  2.423091
# 65      0.0  2.006177
# 199  1125.0  6.915698
# 201  1391.5  3.375524
# 218  2288.0  5.154596
# 219   217.0  2.728588
# 221     0.0  4.471720
# 222   104.0  2.566854
# 227     0.0  2.768123
# 380     0.0  2.505755
# 381   685.0  3.752903
# 426     0.0  6.646141
# 431     0.0  2.602795
# 432     0.0  2.602795
# 437     0.0  2.854381
# 504     0.0  2.135564
# 513     0.0  3.314424
# 555     0.0  5.118655
# 589   573.9  5.704491
# 604     0.0  2.171505
# 605     0.0  3.213790
# 606     0.0  2.926263
# 644   270.0  3.681021
# 649     0.0  2.624360
# 650     0.0  3.012521
# 655   230.0  2.962204
# 656     0.0  3.177849
# 657     0.0  2.387150
# 658     0.0  2.962204
# 659     0.0  3.177849

# %%
# Creation du graphique en nuage de points 
sns.scatterplot(data = table_merge, x=table_merge.index, y='price')
sns.scatterplot(data = table_zscore, x=table_zscore.index ,  y='price')
# Out:
# <AxesSubplot:ylabel='price'>
